# %%
# lets import some required library

import pandas as pd
import numpy as np

# %%
# lets import the movies data 

movies = pd.read_csv('./movielens/movies.csv' , sep=',')
print(type(movies))
movies.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#We can see that this movies.csv file has three variables "movieId", "title", and "genres". Next lets check the number of rows it has 
movies.shape
# Out:
# (62423, 3)

# %%
# lets import the tags data
tags = pd.read_csv('./movielens/tags.csv' , sep=',')
print(type(tags))
tags.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
del tags['timestamp']

# %%
tags.shape
# Out:
# (1093360, 3)

# %% [markdown]
# SO the tag data has four column of variable and has 1093360 rows.

# %%
# now lets import rating file

# %%
ratings = pd.read_csv('./movielens/ratings.csv' , sep=',')
print(type(ratings))
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
ratings.shape
# Out:
# (25000095, 4)

# %% [markdown]
# So ratings has 4 columns and 25000095 samples/rows

# %% [markdown]
# So link has 3 columns and 62423 samples/rows

# %% [markdown]
# # Based on the above exploratory performed, I looking for answering the following questions: #
# *

# %%
tag1 = tags['tag'].unique().tolist()
len(tag1)
# Out:
# 73051

# %%
tag1
# Out:
# ['classic',
#  'sci-fi',
#  'dark comedy',
#  'great dialogue',
#  "so bad it's good",
#  'unreliable narrators',
#  'tense',
#  'artificial intelligence',
#  'philosophical',
#  'cliche',
#  'musical',
#  'horror',
#  'unpredictable',
#  'Oscar (Best Supporting Actress)',
#  'adventure',
#  'anime',
#  'ecology',
#  'fantasy',
#  'Hayao Miyazaki',
#  'Miyazaki',
#  'post-apocalyptic',
#  'bah',
#  'Clint Eastwood',
#  'music',
#  'art',
#  'contemporary art',
#  'documentary',
#  'aliens',
#  'amazing photography',
#  'Director: James Cameron',
#  'first contact',
#  'James Cameron',
#  'Michael Biehn',
#  'android(s)/cyborg(s)',
#  'apocalypse',
#  'Arnold Schwarzenegger',
#  'franchise',
#  'terminator',
#  'time travel',
#  'science fiction',
#  'inferior sequel',
#  'setting:London (UK) (future)',
#  'unoriginal',
#  'bad science',
#  'good science',
#  'Hans Zimmer',
#  'philosophical issues',
#  'space',
#  'space travel',
#  'time-travel',
#  'visually appealing',
# ...

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
tags
# Out:
#          userId  movieId                  tag
# 0             3      260              classic
# 1             3      260               sci-fi
# 2             4     1732          dark comedy
# 3             4     1732       great dialogue
# 4             4     7569     so bad it's good
# ...         ...      ...                  ...
# 1093355  162521    66934  Neil Patrick Harris
# 1093356  162521   103341     cornetto trilogy
# 1093357  162534   189169               comedy
# 1093358  162534   189169             disabled
# 1093359  162534   189169              robbery
#
# [1093360 rows x 3 columns]

# %%
tag_counts=tags['tag'].value_counts()
print(x)
# Out:
# tag
# sci-fi              8330
# atmospheric         6516
# action              5907
# comedy              5702
# surreal             5326
#                     ...
# teen sleuth            1
# evil twins             1
# paternity test         1
# QVC                    1
# cornetto triolgy       1
# Name: count, Length: 73050, dtype: int64

# %%
tag_counts[:10].plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='tag'>

# %%
maxValues = x.max(axis=0)
maxValues
# Out:
# 8330

# %%
movies = pd.read_csv('./movielens/movies.csv' , sep=',')
print(type(movies))
movies.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags.shape
# Out:
# (1093360, 3)

# %%
tags['tag']
# Out:
# 0                      classic
# 1                       sci-fi
# 2                  dark comedy
# 3               great dialogue
# 4             so bad it's good
#                   ...
# 1093355    Neil Patrick Harris
# 1093356       cornetto trilogy
# 1093357                 comedy
# 1093358               disabled
# 1093359                robbery
# Name: tag, Length: 1093360, dtype: object

# %%
tags = tags.dropna()

# %%
tags.shape
# Out:
# (1093344, 3)

# %%
tagscopy = tags.head(500000)

# %%
tagscopy.shape
# Out:
# (500000, 3)

# %%
movies.shape
# Out:
# (62423, 3)

# %%
tag_counts = tags['tag'].value_counts()
tag_counts.shape
# Out:
# (73050,)

# %%
tag_counts.max()
# Out:
# 8330

# %%
ratings = pd.read_csv('./movielens/ratings.csv' , sep=',')
print(type(ratings))
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
del ratings['timestamp']

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1      296     5.0
# 1       1      306     3.5
# 2       1      307     5.0
# 3       1      665     5.0
# 4       1      899     3.5

# %%
ratingcopy = ratings.head(60000) # copy first 600000 rows into ratingcopy from rating

# %%
ratingcopy.columns
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
newdf4 = pd.merge(tagscopy, ratingcopy, on="movieId", how="inner")
newdf4.head(10)
# Out:
#    userId_x  movieId      tag  userId_y  rating
# 0         3      260  classic         2     5.0
# 1         3      260  classic         3     4.0
# 2         3      260  classic         4     3.5
# 3         3      260  classic         5     5.0
# 4         3      260  classic         6     5.0
# 5         3      260  classic         8     3.0
# 6         3      260  classic         9     4.0
# 7         3      260  classic        10     5.0
# 8         3      260  classic        12     5.0
# 9         3      260  classic        13     4.5

# %%
newdf4['tag']=newdf4['tag'].astype('category').cat.codes
newdf4['rating']=newdf4['rating'].astype('category').cat.codes
newdf4.corr()
# Out:
#           userId_x   movieId       tag  userId_y    rating
# userId_x  1.000000  0.007293 -0.050806  0.001506  0.014987
# movieId   0.007293  1.000000 -0.008058  0.017581 -0.057880
# tag      -0.050806 -0.008058  1.000000 -0.000633  0.018766
# userId_y  0.001506  0.017581 -0.000633  1.000000 -0.011507
# rating    0.014987 -0.057880  0.018766 -0.011507  1.000000

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
ratings.shape
# Out:
# (25000095, 3)

# %%
newdf = pd.merge(movies, ratings, on="movieId", how="inner")
newdf.head(10)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 5        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 6        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 7        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 8        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 9        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating
# 0       2     3.5
# 1       3     4.0
# 2       4     3.0
# 3       5     4.0
# 4       8     4.0
# 5      10     3.5
# ...

# %%
#corr = newdf['genres'].corr(newdf['rating'])

# %%
#tagsrating = tagsrating.dropna()

# %%
#tagsrating

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
del df2['title']

# %%
df2
# Out:
#           movieId                                       genres  userId  rating
# 0               1  Adventure|Animation|Children|Comedy|Fantasy       2     3.5
# 1               1  Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 2               1  Adventure|Animation|Children|Comedy|Fantasy       4     3.0
# 3               1  Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# 4               1  Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# ...           ...                                          ...     ...     ...
# 25000090   209157                                        Drama  119571     1.5
# 25000091   209159                                  Documentary  115835     3.0
# 25000092   209163                                 Comedy|Drama    6964     4.5
# 25000093   209169                           (no genres listed)  119571     3.0
# 25000094   209171                       Action|Adventure|Drama  119571     3.0
#
# ...

# %%
df2['genres']=df2['genres'].astype('category').cat.codes
df2['rating']=df2['rating'].astype('category').cat.codes
df2.corr()
# Out:
#           movieId    genres    userId    rating
# movieId  1.000000 -0.052287 -0.004413 -0.009216
# genres  -0.052287  1.000000 -0.000726  0.048385
# userId  -0.004413 -0.000726  1.000000  0.001940
# rating  -0.009216  0.048385  0.001940  1.000000
